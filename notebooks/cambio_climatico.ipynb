# %% [markdown]
# ## importacion de librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## cargar dataset

# %%
df = pd.read_csv('../data/raw/temperature-anomaly.csv')

# %% [markdown]
# ## Inspección rápida

# %%
df.head(), df.tail(), df.shape
# Out:
# (                Entity     Code  Year   Average  Lower bound  Upper bound
#  0  Northern Hemisphere  OWID_NH  1850 -0.055067    -0.254982     0.144848
#  1  Northern Hemisphere  OWID_NH  1851  0.161580    -0.047569     0.370729
#  2  Northern Hemisphere  OWID_NH  1852  0.145127    -0.076860     0.367114
#  3  Northern Hemisphere  OWID_NH  1853  0.135437    -0.082370     0.353244
#  4  Northern Hemisphere  OWID_NH  1854  0.206140     0.009939     0.402340,
#      Entity      Code  Year   Average  Lower bound  Upper bound
#  523  World  OWID_WRL  2021  1.131273     1.096345     1.166200
#  524  World  OWID_WRL  2022  1.165803     1.128758     1.202849
#  525  World  OWID_WRL  2023  1.473764     1.436804     1.510725
#  526  World  OWID_WRL  2024  1.533446     1.494273     1.572618
#  527  World  OWID_WRL  2025  1.413232     1.373787     1.452677,
#  (528, 6))

# %% [markdown]
# ## Diagnóstico principal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Entity       528 non-null    object
#  1   Code         352 non-null    object
#  2   Year         528 non-null    int64
#  3   Average      528 non-null    float64
#  4   Lower bound  528 non-null    float64
#  5   Upper bound  528 non-null    float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 24.9+ KB

# %% [markdown]
# ## Resumen estadístico

# %%
df.describe(), df.describe(include='object')
# Out:
# (              Year     Average  Lower bound  Upper bound
#  count   528.000000  528.000000   528.000000   528.000000
#  mean   1937.500000    0.304255     0.195300     0.413209
#  std      50.854184    0.411368     0.453811     0.374979
#  min    1850.000000   -0.320683    -0.566759    -0.134624
#  25%    1893.750000    0.006610    -0.160847     0.162610
#  50%    1937.500000    0.167542     0.080186     0.301660
#  75%    1981.250000    0.484214     0.424603     0.572812
#  max    2025.000000    1.937535     1.884537     2.196952,
#                       Entity     Code
#  count                   528      352
#  unique                    3        2
#  top     Northern Hemisphere  OWID_NH
#  freq                    176      176)
